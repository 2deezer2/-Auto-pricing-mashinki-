# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)

# %%
import requests #Библиотека для запроса
import pandas as pd
# https://youtu.be/CznaOZaGTz0
a = 1 #Переменная для перехода по страницам
Custom = list()
Number_of_owners = list()
Year = list()
Price = list()
Region = list()
Mileage = list()
Brand = list()
Model = list()
Power = list()
Type = list()
Engine_type = list()
korobka = list()
info = {'Custom': Custom, 'Number_of_owners': Number_of_owners,'Year': Year, 
        'Price': Price, 'Region' :Region, 'Mileage': Mileage, 
        'Brand': Brand, 'Model': Model, 'Power': Power, 'Type': Type, 
        'Engine_type': Engine_type, "Transmission": korobka}


while a <= 1809: #Всего 99 страниц на сайте
    URL = 'https://auto.ru/-/ajax/desktop/listing/' #URL на который будет отправлен запрос

    #Параметры запроса
    PARAMS = {
         'section': "all",
         'category': "cars",
         'sort': "fresh_relevance_1-desc",
         'page': a
        }
    #Заголовки страницы
    HEADERS = {
        'Accept': '*/*',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
        'Connection': 'keep-alive',
        'Content-Length': '137',
        'content-type': 'application/json',
        'Cookie': '_csrf_token=1c0ed592ec162073ac34d79ce511f0e50d195f763abd8c24; autoru_sid=a%3Ag5e3b198b299o5jhpv6nlk0ro4daqbpf.fa3630dbc880ea80147c661111fb3270%7C1580931467355.604800.8HnYnADZ6dSuzP1gctE0Fw.cd59AHgDSjoJxSYHCHfDUoj-f2orbR5pKj6U0ddu1G4; autoruuid=g5e3b198b299o5jhpv6nlk0ro4daqbpf.fa3630dbc880ea80147c661111fb3270; suid=48a075680eac323f3f9ad5304157467a.bc50c5bde34519f174ccdba0bd791787; from_lifetime=1580933172327; from=yandex; X-Vertis-DC=myt; crookie=bp+bI7U7P7sm6q0mpUwAgWZrbzx3jePMKp8OPHqMwu9FdPseXCTs3bUqyAjp1fRRTDJ9Z5RZEdQLKToDLIpc7dWxb90=; cmtchd=MTU4MDkzMTQ3MjU0NQ==; yandexuid=1758388111580931457; bltsr=1; navigation_promo_seen-recalls=true',
        'Host': 'auto.ru',
        'origin': 'https://auto.ru',
        'Referer': 'https://auto.ru/moskovskaya_oblast/cars/used/',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0',
        'x-client-app-version': '202002.03.092255',
        'x-client-date': '1580933207763',
        'x-csrf-token': '1c0ed592ec162073ac34d79ce511f0e50d195f763abd8c24',
        'x-page-request-id': '60142cd4f0c0edf51f96fd0134c6f02a',
        'x-requested-with': 'fetch'
    }

    response = requests.post(URL, json=PARAMS, headers=HEADERS)
    data = response.json()['offers'] #Переменная data хранит полученные объявления

    i = 0 
    while i <= len(data) - 1:

        #Растаможен ли автомобиль (возвращает True или False)
        Custom.append(int(bool(data[i]['documents']['custom_cleared'])))

        #Колличество владельцев автомобиля
        Number_of_owners.append(int(data[i]['documents']['owners_number']))

        #Год выпуска автомобиля
        Year.append(int(data[i]['documents']['year']))

        #Цена в рублях
        Price.append(float(data[i]['price_info']['RUR']))

        #Тип двигателя
        Engine_type.append(data[i]['vehicle_info']['tech_param']['engine_type'])

        #Коробка передач
        korobka.append(data[i]['vehicle_info']['tech_param']['transmission'])

        #Регион, в котором находится автомобиль
        Region.append(str(data[i]['seller']['location']['region_info']['name']))
        
        #Пробег автомобиля
        Mileage.append(float(data[i]['state']['mileage']))

        #Объём двигателя пока не смог вытащить, но позже думаю можно

        #Лошадиные силы
        Power.append(float(data[i]['vehicle_info']['tech_param']['power']))

        #Название автомобиля
        Type.append(str(data[i]['vehicle_info']['configuration']['human_name']))

        #Марка автомобиля
        Brand.append(str(data[i]['vehicle_info']['mark_info']['name']))

        #Модель автомобиля
        Model.append(str(data[i]['vehicle_info']['model_info']['name']))

        i += 1 #Увеличиваем переменную перехода по объявлениям на 1
    a += 1 #Увеличиваем переменную страницы сайта на 1

df = pd.DataFrame(info)
df
# Out:
#        Custom  Number_of_owners  Year       Price  Region   Mileage  \
# 0           1                 4  2007    300000.0  Москва  130000.0
# 1           1                 3  2002    280000.0  Москва  197000.0
# 2           1                 1  2007    360000.0  Москва  117000.0
# 3           1                 4  2008    450000.0  Москва  191000.0
# 4           1                 2  2006    500000.0  Москва  233000.0
# ...       ...               ...   ...         ...     ...       ...
# 66928       1                 1  2022   2650000.0  Москва   19000.0
# 66929       1                 2  2021   4500000.0  Москва   13000.0
# 66930       1                 2  2015   4600000.0  Москва  110000.0
# 66931       1                 2  2020  10100000.0  Москва   52000.0
# 66932       1                 4  2013    650000.0  Москва  233000.0
#
#                Brand        Model  Power               Type Engine_type  \
# 0             Suzuki        Swift   92.0      Хэтчбек 5 дв.    GASOLINE
# 1                Kia     Sportage   91.0  Внедорожник 5 дв.      DIESEL
# 2            Hyundai       Accent  105.0              Седан    GASOLINE
# 3          Chevrolet      Lacetti  121.0    Универсал 5 дв.    GASOLINE
# 4             Toyota      Corolla  110.0      Хэтчбек 5 дв.    GASOLINE
# ...              ...          ...    ...                ...         ...
# 66928     Volkswagen         Taos  150.0  Внедорожник 5 дв.    GASOLINE
# 66929  Mercedes-Benz          GLC  197.0  Внедорожник 5 дв.    GASOLINE
# 66930     Land Rover  Range Rover  248.0  Внедорожник 5 дв.      DIESEL
# 66931     Land Rover  Range Rover  300.0  Внедорожник 5 дв.      HYBRID
# 66932           Ford        Focus  105.0    Универсал 5 дв.    GASOLINE
#
#       Transmission
# 0       MECHANICAL
# 1       MECHANICAL
# 2       MECHANICAL
# 3       MECHANICAL
# 4        AUTOMATIC
# ...            ...
# 66928    AUTOMATIC
# 66929    AUTOMATIC
# 66930    AUTOMATIC
# 66931    AUTOMATIC
# 66932   MECHANICAL
#
# [66933 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# Custom              0
# Number_of_owners    0
# Year                0
# Price               0
# Region              0
# Mileage             0
# Brand               0
# Model               0
# Power               0
# Type                0
# Engine_type         0
# Transmission        0
# dtype: int64

# %%
data = response.json()['offers']
data[5]
# Out:
# {'availability': 'IN_STOCK',
#  'color_hex': '040001',
#  'delivery_info': {},
#  'discount_options': {},
#  'documents': {'owners_number': 1,
#   'pts_original': True,
#   'custom_cleared': True,
#   'purchase_date': {'year': 2021, 'month': 3},
#   'year': 2021,
#   'vin': 'Z94**************',
#   'warranty': True,
#   'warranty_expire': {'year': 2026, 'month': 3, 'day': 1},
#   'pts': 'ORIGINAL',
#   'license_plate': '******|777',
#   'vin_resolution': 'OK'},
#  'is_favorite': False,
#  'old_category_id': 15,
#  'owner_expenses': {'transport_tax': {'tax_by_year': 5215,
#    'year': 2023,
#    'rid': 213,
#    'rate': 35,
#    'horse_power': 149,
#    'holding_period_month': 12,
#    'boost': 1}},
#  'score': {'transparency': 88, 'price': 0.5, 'health': 93},
#  'services': [{'service': 'all_sale_fresh',
#    'create_date': '1684180787376',
#    'is_active': True,
#    'prolongable': False}],
#  'status': 'ACTIVE',
#  'tags': ['stable_price',
#   'oversize',
#   'compact',
#   'available_for_c2b_auction',
#   'novice-drivers',
#   'medium',
#   'increased_price',
#   'comfort',
#   'allowed_for_credit',
#   'available_for_carp_auction',
#   'autoru_exclusive',
#   'liquid',
#   'all-terrain',
#   'vin_offers_history',
#   'allowed_for_safe_deal',
#   'available_for_checkup',
#   'handling',
#   'vin_resolution_ok',
#   'economical',
#   'fresh',
#   'vin_checked',
#   'no_accidents',
#   'one_owner',
#   'warranty',
#   'high_reviews_mark',
#   'low_mileage',
#   'pts_original',
#   'real_photo',
#   'preset.avto_dlya_novichka',
#   'preset.top_koreyskih_avto',
#   'withNumericFeaturePairs'],
#  'predicted_price_ranges': {'q4060': {'from': 1890000,
#    'to': 1960000,
#    'currency': 'RUR'},
#   'trade_in': {'from': 1810000, 'to': 1870000, 'currency': 'RUR'},
#   'tag_range': {'from': 1744000, 'to': 1993000, 'currency': 'RUR'}},
#  'user_ref': 'user:25547364',
#  'additional_info': {'hidden': False,
#   'is_on_moderation': False,
#   'update_date': '1684180865000',
#   'creation_date': '1682542576000',
#   'hot_info': {'is_hot': False,
#    'start_time': '2023-04-26T20:56:16Z',
#    'end_time': '2023-04-26T20:56:16Z'},
#   'fresh_date': '1682542576000',
#   'counters_start_date': '1682542576000',
#   'chat_only': False,
#   'dealer_card_promo': 'DONT_SHOW',
#   'review_summary': {'avg_rating': 4.699999809265137, 'counter': 21},
#   'price_stats': {'last_year_price_percentage_diff': -3},
#   'booking': {},
#   'days_in_stock': 19,
#   'days_on_sale': 19,
#   'can_view': False,
#   'trusted_dealer_calls_accepted': True,
#   'app2app_calls_disabled': False,
#   'other_offers_show_info': {'encrypted_user_id': 'nJfBb4wAAkDtbJN8CSLT9JZ1IiVlNsN_aRisOopzIlg'},
#   'displayed_creation_date': '1682542576000',
#   'calls_and_messages_only_from_verified': False},
#  'category': 'cars',
#  'counters': {},
#  'hash': '5f2b0d54',
#  'id': '1118849019',
#  'multiposting': {},
#  'price_info': {'price': 2100000,
#   'currency': 'RUR',
#   'EUR': 24394,
#   'RUR': 2100000,
#   'USD': 26549,
#   'with_nds': False},
#  'price_history': [{'EUR': 24394,
#    'RUR': 2100000,
#    'USD': 26549,
#    'create_timestamp': 1682540170000}],
#  'saleId': '1118849019-5f2b0d54',
#  'salon': {'is_oficial': False, 'place': {}, 'is_official': False},
#  'section': 'used',
#  'seller': {'location': {'address': 'улица Татьянин Парк, ',
#    'coord': {'latitude': 55.755863, 'longitude': 37.617699},
#    'geobase_id': '213',
#    'region_info': {'id': '213',
#     'name': 'Москва',
#     'genitive': 'Москвы',
#     'dative': 'Москве',
#     'accusative': 'Москву',
#     'prepositional': 'Москве',
#     'preposition': 'в',
#     'latitude': 55.755863,
#     'longitude': 37.6177,
#     'parent_ids': ['213', '1', '3', '225', '10001', '10000']},
#    'timezone_info': {'name': 'Europe/Moscow',
#     'abbr': 'MSK',
#     'offset': 10800,
#     'dst': False}},
#   'name': 'cirilocardoso11',
#   'phones': [],
#   'redirect_phones': True,
#   'chats_enabled': True,
#   'call_hours': {'call_hour_start': 0, 'call_hour_end': 0}},
#  'seller_type': 'PRIVATE',
#  'service_prices': [],
#  'state': {'condition': 'CONDITION_OK',
#   'mileage': 55000,
#   'image_urls': [{'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2142482/42ad9e36bc5eaed341600af06cc996ee/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2142482/42ad9e36bc5eaed341600af06cc996ee/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2142482/42ad9e36bc5eaed341600af06cc996ee/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2142482/42ad9e36bc5eaed341600af06cc996ee/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2142482/42ad9e36bc5eaed341600af06cc996ee/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2142482/42ad9e36bc5eaed341600af06cc996ee/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2142482/42ad9e36bc5eaed341600af06cc996ee/1200x900n'},
#     'photo_class': 'AUTO_VIEW_FRONT_RIGHT',
#     'name': '1',
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2087497/235d0eea44d1267db540551e2e81cad4/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2087497/235d0eea44d1267db540551e2e81cad4/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2087497/235d0eea44d1267db540551e2e81cad4/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2087497/235d0eea44d1267db540551e2e81cad4/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2087497/235d0eea44d1267db540551e2e81cad4/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2087497/235d0eea44d1267db540551e2e81cad4/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2087497/235d0eea44d1267db540551e2e81cad4/1200x900n'},
#     'photo_class': 'AUTO_VIEW_BACK_LEFT',
#     'name': '2',
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2165806/b86f060c65ba821ab417941e3bdf6a2d/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2165806/b86f060c65ba821ab417941e3bdf6a2d/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2165806/b86f060c65ba821ab417941e3bdf6a2d/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2165806/b86f060c65ba821ab417941e3bdf6a2d/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2165806/b86f060c65ba821ab417941e3bdf6a2d/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2165806/b86f060c65ba821ab417941e3bdf6a2d/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2165806/b86f060c65ba821ab417941e3bdf6a2d/1200x900n'},
#     'photo_class': 'AUTO_VIEW_SALON_FRONT_LEFT',
#     'name': '3',
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2074437/37923d25c41b014d9b9862fd6cc81681/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2074437/37923d25c41b014d9b9862fd6cc81681/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2074437/37923d25c41b014d9b9862fd6cc81681/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2074437/37923d25c41b014d9b9862fd6cc81681/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2074437/37923d25c41b014d9b9862fd6cc81681/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2074437/37923d25c41b014d9b9862fd6cc81681/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2074437/37923d25c41b014d9b9862fd6cc81681/1200x900n'},
#     'photo_class': 'AUTO_VIEW_SALON_FRONT_LEFT',
#     'name': '4',
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/1894638/ae6452a74ada0c4cf5a3856b6485baac/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/1894638/ae6452a74ada0c4cf5a3856b6485baac/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/1894638/ae6452a74ada0c4cf5a3856b6485baac/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/1894638/ae6452a74ada0c4cf5a3856b6485baac/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/1894638/ae6452a74ada0c4cf5a3856b6485baac/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/1894638/ae6452a74ada0c4cf5a3856b6485baac/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/1894638/ae6452a74ada0c4cf5a3856b6485baac/1200x900n'},
#     'photo_class': 'AUTO_VIEW_SALON_FRONT_LEFT',
#     'name': '5',
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/1870663/7718c5a2d4caf87f1908399c6664a7c5/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/1870663/7718c5a2d4caf87f1908399c6664a7c5/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/1870663/7718c5a2d4caf87f1908399c6664a7c5/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/1870663/7718c5a2d4caf87f1908399c6664a7c5/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/1870663/7718c5a2d4caf87f1908399c6664a7c5/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/1870663/7718c5a2d4caf87f1908399c6664a7c5/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/1870663/7718c5a2d4caf87f1908399c6664a7c5/1200x900n'},
#     'photo_class': 'AUTO_VIEW_SALON_BACK_LEFT',
#     'name': '6',
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2160224/0bb599c263d9ee70cd3ae11912a3589e/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2160224/0bb599c263d9ee70cd3ae11912a3589e/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2160224/0bb599c263d9ee70cd3ae11912a3589e/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2160224/0bb599c263d9ee70cd3ae11912a3589e/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2160224/0bb599c263d9ee70cd3ae11912a3589e/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2160224/0bb599c263d9ee70cd3ae11912a3589e/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2160224/0bb599c263d9ee70cd3ae11912a3589e/1200x900n'},
#     'photo_class': 'AUTO_VIEW_SALON_BACK_RIGHT',
#     'name': '7',
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/1713967/8ab49656b80780e56fc7dfc23e4e7c79/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/1713967/8ab49656b80780e56fc7dfc23e4e7c79/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/1713967/8ab49656b80780e56fc7dfc23e4e7c79/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/1713967/8ab49656b80780e56fc7dfc23e4e7c79/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/1713967/8ab49656b80780e56fc7dfc23e4e7c79/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/1713967/8ab49656b80780e56fc7dfc23e4e7c79/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/1713967/8ab49656b80780e56fc7dfc23e4e7c79/1200x900n'},
#     'photo_class': 'AUTO_VIEW_PP_RIGHT',
#     'name': '8',
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2104847/534ebc196a4fc037f3f18571563d3d84/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2104847/534ebc196a4fc037f3f18571563d3d84/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2104847/534ebc196a4fc037f3f18571563d3d84/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2104847/534ebc196a4fc037f3f18571563d3d84/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2104847/534ebc196a4fc037f3f18571563d3d84/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2104847/534ebc196a4fc037f3f18571563d3d84/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2104847/534ebc196a4fc037f3f18571563d3d84/1200x900n'},
#     'photo_class': 'AUTO_VIEW_PP_RIGHT',
#     'name': '9',
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2058167/49f69d899db22bae68c7c46b196e1191/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2058167/49f69d899db22bae68c7c46b196e1191/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2058167/49f69d899db22bae68c7c46b196e1191/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2058167/49f69d899db22bae68c7c46b196e1191/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2058167/49f69d899db22bae68c7c46b196e1191/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2058167/49f69d899db22bae68c7c46b196e1191/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2058167/49f69d899db22bae68c7c46b196e1191/1200x900n'},
#     'photo_class': 'AUTO_VIEW_SALON_FRONT_RIGHT',
#     'name': '10',
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2165132/4d625e266ba5b73a731522ff3f07f0e5/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2165132/4d625e266ba5b73a731522ff3f07f0e5/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2165132/4d625e266ba5b73a731522ff3f07f0e5/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2165132/4d625e266ba5b73a731522ff3f07f0e5/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2165132/4d625e266ba5b73a731522ff3f07f0e5/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2165132/4d625e266ba5b73a731522ff3f07f0e5/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2165132/4d625e266ba5b73a731522ff3f07f0e5/1200x900n'},
#     'photo_class': 'AUTO_VIEW_3_4_BACK_RIGHT',
#     'name': '11',
#     'preview': 'data:image/jpeg;base64,...'}],
#   'images_count': 22},
#  'sub_category': 'cars',
#  'vehicle_info': {'configuration': {'body_type': 'ALLROAD_5_DOORS',
#    'id': '21831481',
#    'doors_count': 5,
#    'human_name': 'Внедорожник 5 дв.',
#    'main_photo': {'name': 'configuration-photo',
#     'sizes': {'main': '//avatars.mds.yandex.net/get-verba/1540742/2a00000170cf371dfeecd31a973c70532c7c/gallery',
#      'mini-card': '//avatars.mds.yandex.net/get-verba/1540742/2a00000170cf371dfeecd31a973c70532c7c/minicard',
#      'mobile': '//avatars.mds.yandex.net/get-verba/1540742/2a00000170cf371dfeecd31a973c70532c7c/auto_main',
#      'orig': '//avatars.mds.yandex.net/get-verba/1540742/2a00000170cf371dfeecd31a973c70532c7c/orig',
#      'wizardv3mr': '//avatars.mds.yandex.net/get-verba/1540742/2a00000170cf371dfeecd31a973c70532c7c/wizardv3mr',
#      'cattouch': '//avatars.mds.yandex.net/get-verba/1540742/2a00000170cf371dfeecd31a973c70532c7c/cattouch'}}},
#   'complectation': {'id': '0'},
#   'equipment': {'engine-proof': True,
#    'remote-engine-start': True,
#    'windscreen-heat': True,
#    'heated-wash-system': True},
#   'mark_info': {'code': 'HYUNDAI',
#    'name': 'Hyundai',
#    'ru_name': 'Хендай',
#    'logo': {'name': 'mark-logo',
#     'sizes': {'logo': '//avatars.mds.yandex.net/get-verba/1030388/2a00000179b3bf9ed4cee7a9032a7849da57/logo',
#      'big-logo': '//avatars.mds.yandex.net/get-verba/1030388/2a00000179b3bf9ed4cee7a9032a7849da57/dealer_logo',
#      'black-logo': '//avatars.mds.yandex.net/get-verba/937147/2a00000179b3bfc82a10066df20e76cc1dfb/logo'}},
#    'numeric_id': '3157'},
#   'model_info': {'code': 'CRETA', 'name': 'Creta', 'ru_name': 'Крета'},
#   'steering_wheel': 'LEFT',
#   'super_gen': {'id': '21831433',
#    'name': 'I Рестайлинг',
#    'ru_name': '1 Рестайлинг',
#    'year_from': 2020,
#    'year_to': 2021,
#    'price_segment': 'MEDIUM',
#    'purpose_group': 'CITY'},
#   'tech_param': {'gear_type': 'FORWARD_CONTROL',
#    'engine_type': 'GASOLINE',
#    'transmission': 'AUTOMATIC',
#    'id': '21831487',
#    'name': '',
#    'nameplate': '',
#    'displacement': 1999,
#    'power': 149,
#    'power_kvt': 110,
#    'human_name': '2.0 AT (149 л.с.)'},
#   'vendor': 'KOREAN'},
#  'recommendation_tags': []}

# %%
# Out:
# 1
