# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)

# %%
import requests #Библиотека для запроса
import pandas as pd
# https://youtu.be/CznaOZaGTz0
a = 1 #Переменная для перехода по страницам
Custom = list()
Number_of_owners = list()
Year = list()
Price = list()
Region = list()
Mileage = list()
Brand = list()
Model = list()
Power = list()
Type = list()
Engine_type = list()
korobka = list()
info = {'Custom': Custom, 'Number_of_owners': Number_of_owners,'Year': Year, 
        'Price': Price, 'Region' :Region, 'Mileage': Mileage, 
        'Brand': Brand, 'Model': Model, 'Power': Power, 'Type': Type, 
        'Engine_type': Engine_type, "Transmission": korobka}


while a <= 1809: #Всего 99 страниц на сайте
    URL = 'https://auto.ru/-/ajax/desktop/listing/' #URL на который будет отправлен запрос

    #Параметры запроса
    PARAMS = {
         'section': "all",
         'category': "cars",
         'sort': "fresh_relevance_1-desc",
         'page': a
        }
    #Заголовки страницы
    HEADERS = {
        'Accept': '*/*',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
        'Connection': 'keep-alive',
        'Content-Length': '137',
        'content-type': 'application/json',
        'Cookie': '_csrf_token=1c0ed592ec162073ac34d79ce511f0e50d195f763abd8c24; autoru_sid=a%3Ag5e3b198b299o5jhpv6nlk0ro4daqbpf.fa3630dbc880ea80147c661111fb3270%7C1580931467355.604800.8HnYnADZ6dSuzP1gctE0Fw.cd59AHgDSjoJxSYHCHfDUoj-f2orbR5pKj6U0ddu1G4; autoruuid=g5e3b198b299o5jhpv6nlk0ro4daqbpf.fa3630dbc880ea80147c661111fb3270; suid=48a075680eac323f3f9ad5304157467a.bc50c5bde34519f174ccdba0bd791787; from_lifetime=1580933172327; from=yandex; X-Vertis-DC=myt; crookie=bp+bI7U7P7sm6q0mpUwAgWZrbzx3jePMKp8OPHqMwu9FdPseXCTs3bUqyAjp1fRRTDJ9Z5RZEdQLKToDLIpc7dWxb90=; cmtchd=MTU4MDkzMTQ3MjU0NQ==; yandexuid=1758388111580931457; bltsr=1; navigation_promo_seen-recalls=true',
        'Host': 'auto.ru',
        'origin': 'https://auto.ru',
        'Referer': 'https://auto.ru/moskovskaya_oblast/cars/used/',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0',
        'x-client-app-version': '202002.03.092255',
        'x-client-date': '1580933207763',
        'x-csrf-token': '1c0ed592ec162073ac34d79ce511f0e50d195f763abd8c24',
        'x-page-request-id': '60142cd4f0c0edf51f96fd0134c6f02a',
        'x-requested-with': 'fetch'
    }

    response = requests.post(URL, json=PARAMS, headers=HEADERS)
    data = response.json()['offers'] #Переменная data хранит полученные объявления

    i = 0 
    while i <= len(data) - 1:

        #Растаможен ли автомобиль (возвращает True или False)
        Custom.append(int(bool(data[i]['documents']['custom_cleared'])))

        #Колличество владельцев автомобиля
        Number_of_owners.append(int(data[i]['documents']['owners_number']))

        #Год выпуска автомобиля
        Year.append(str(data[i]['documents']['year']))

        #Цена в рублях
        Price.append(float(data[i]['price_info']['RUR']))

        #Тип двигателя
        Engine_type.append(data[i]['vehicle_info']['tech_param']['engine_type'])

        #Коробка передач
        korobka.append(data[i]['vehicle_info']['tech_param']['transmission'])

        #Регион, в котором находится автомобиль
        Region.append(str(data[i]['seller']['location']['region_info']['name']))
        
        #Пробег автомобиля
        Mileage.append(float(data[i]['state']['mileage']))

        #Объём двигателя пока не смог вытащить, но позже думаю можно

        #Лошадиные силы
        Power.append(float(data[i]['vehicle_info']['tech_param']['power']))

        #Название автомобиля
        Type.append(str(data[i]['vehicle_info']['configuration']['human_name']))

        #Марка автомобиля
        Brand.append(str(data[i]['vehicle_info']['mark_info']['name']))

        #Модель автомобиля
        Model.append(str(data[i]['vehicle_info']['model_info']['name']))

        i += 1 #Увеличиваем переменную перехода по объявлениям на 1
    a += 1 #Увеличиваем переменную страницы сайта на 1

df = pd.DataFrame(info)
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-db6771d7c232> in <cell line: 23>()
#      51     }
#      52
# ---> 53     response = requests.post(URL, json=PARAMS, headers=HEADERS)
#      54     data = response.json()['offers'] #Переменная data хранит полученные объявления
#      55
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in post(url, data, json, **kwargs)
#     115     """
#     116
# --> 117     return request('post', url, data=data, json=json, **kwargs)
#     118
#     119
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438         try:
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#     442                     url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384         # Trigger any extra validation we need to do.
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#     388             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1040         # Force connect early to allow us to validate the connection.
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#    1044         if not conn.is_verified:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in connect(self)
#     361     def connect(self):
#     362         # Add certificate verification
# --> 363         self.sock = conn = self._new_conn()
#     364         hostname = self.host
#     365         tls_in_tls = False
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in _new_conn(self)
#     172
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      70         )
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#      74         sock = None
#
# /usr/lib/python3.10/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     # and socket type values to enum constants.
#     954     addrlist = []
# --> 955     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956         af, socktype, proto, canonname, sa = res
#     957         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:

# %%
df.isna().sum()
# Out:
# Custom              0
# Number_of_owners    0
# Year                0
# Price               0
# Region              0
# Mileage             0
# Brand               0
# Model               0
# Power               0
# Type                0
# Engine_type         0
# Transmission        0
# dtype: int64

# %%
data = response.json()['offers']
data[5]
# Out:
# {'availability': 'IN_STOCK',
#  'color_hex': 'FAFBFB',
#  'delivery_info': {},
#  'discount_options': {},
#  'documents': {'owners_number': 1,
#   'pts_original': True,
#   'custom_cleared': True,
#   'year': 2016,
#   'vin': 'JTJ**************',
#   'pts': 'ORIGINAL',
#   'license_plate': '******|40',
#   'vin_resolution': 'OK'},
#  'is_favorite': False,
#  'old_category_id': 15,
#  'owner_expenses': {'transport_tax': {'tax_by_year': 44400,
#    'year': 2023,
#    'rid': 213,
#    'rate': 150,
#    'horse_power': 296,
#    'holding_period_month': 12,
#    'boost': 1}},
#  'score': {'transparency': 88, 'price': 0.5, 'health': 86},
#  'status': 'ACTIVE',
#  'tags': ['big',
#   'oversize',
#   'available_for_c2b_auction',
#   'vin_service_history',
#   'allowed_for_cartinder',
#   'prestige',
#   'comfort',
#   'allowed_for_credit',
#   'available_for_carp_auction',
#   'autoru_exclusive',
#   'liquid',
#   'wide-back-seats',
#   'big-trunk',
#   'all-terrain',
#   'vin_offers_history',
#   'predict_match_price',
#   'allowed_for_safe_deal',
#   'available_for_checkup',
#   'vin_resolution_ok',
#   'offroad',
#   'vin_checked',
#   'frame',
#   'no_accidents',
#   'one_owner',
#   'high_reviews_mark',
#   'pts_original',
#   'real_photo'],
#  'predicted_price_ranges': {'q4060': {'from': 4100000,
#    'to': 4260000,
#    'currency': 'RUR'},
#   'trade_in': {'from': 3860000, 'to': 4000000, 'currency': 'RUR'},
#   'tag_range': {'from': 3795000, 'to': 4382000, 'currency': 'RUR'}},
#  'user_ref': 'user:56651040',
#  'additional_info': {'hidden': False,
#   'is_on_moderation': False,
#   'exchange': True,
#   'update_date': '1684172929000',
#   'creation_date': '1684172579000',
#   'hot_info': {'is_hot': False,
#    'start_time': '2023-05-15T17:42:59Z',
#    'end_time': '2023-05-15T17:42:59Z'},
#   'fresh_date': '1684172579000',
#   'counters_start_date': '1684172579000',
#   'chat_only': False,
#   'dealer_card_promo': 'DONT_SHOW',
#   'review_summary': {'avg_rating': 4.699999809265137, 'counter': 14},
#   'price_stats': {},
#   'booking': {},
#   'days_in_stock': 1,
#   'days_on_sale': 1,
#   'can_view': False,
#   'trusted_dealer_calls_accepted': True,
#   'app2app_calls_disabled': False,
#   'other_offers_show_info': {'encrypted_user_id': 'opppN7IcXKSEvt6BuSGowmfSPCV4TqJD2yoGTaqNrBc'},
#   'displayed_creation_date': '1684172579000',
#   'calls_and_messages_only_from_verified': False},
#  'category': 'cars',
#  'counters': {},
#  'hash': 'f9cb59da',
#  'id': '1119046035',
#  'multiposting': {},
#  'price_info': {'price': 4250000,
#   'currency': 'RUR',
#   'EUR': 49369,
#   'RUR': 4250000,
#   'USD': 53729,
#   'with_nds': False},
#  'price_history': [{'EUR': 49369,
#    'RUR': 4250000,
#    'USD': 53729,
#    'create_timestamp': 1684172561000}],
#  'saleId': '1119046035-f9cb59da',
#  'salon': {'is_oficial': False, 'place': {}, 'is_official': False},
#  'section': 'used',
#  'seller': {'location': {'address': 'ул. 4-я Новые сады. ',
#    'coord': {'latitude': 55.755863, 'longitude': 37.617699},
#    'geobase_id': '213',
#    'region_info': {'id': '213',
#     'name': 'Москва',
#     'genitive': 'Москвы',
#     'dative': 'Москве',
#     'accusative': 'Москву',
#     'prepositional': 'Москве',
#     'preposition': 'в',
#     'latitude': 55.755863,
#     'longitude': 37.6177,
#     'parent_ids': ['213', '1', '3', '225', '10001', '10000']},
#    'timezone_info': {'name': 'Europe/Moscow',
#     'abbr': 'MSK',
#     'offset': 10800,
#     'dst': False}},
#   'name': 'Юрий',
#   'phones': [],
#   'redirect_phones': False,
#   'chats_enabled': True,
#   'call_hours': {'call_hour_start': 0, 'call_hour_end': 0}},
#  'seller_type': 'PRIVATE',
#  'service_prices': [],
#  'services': [],
#  'state': {'condition': 'CONDITION_OK',
#   'mileage': 170000,
#   'image_urls': [{'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/1998168/89db256bacd5311200ec09cd060fe3b1/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/1998168/89db256bacd5311200ec09cd060fe3b1/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/1998168/89db256bacd5311200ec09cd060fe3b1/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/1998168/89db256bacd5311200ec09cd060fe3b1/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/1998168/89db256bacd5311200ec09cd060fe3b1/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/1998168/89db256bacd5311200ec09cd060fe3b1/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/1998168/89db256bacd5311200ec09cd060fe3b1/1200x900n'},
#     'photo_class': 'AUTO_VIEW_FRONT_LEFT',
#     'name': '11',
#     'is_hd': True,
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/1907895/c869e1a260c04f35768f40d3d82fe133/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/1907895/c869e1a260c04f35768f40d3d82fe133/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/1907895/c869e1a260c04f35768f40d3d82fe133/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/1907895/c869e1a260c04f35768f40d3d82fe133/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/1907895/c869e1a260c04f35768f40d3d82fe133/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/1907895/c869e1a260c04f35768f40d3d82fe133/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/1907895/c869e1a260c04f35768f40d3d82fe133/1200x900n'},
#     'photo_class': 'AUTO_VIEW_3_4_BACK_RIGHT',
#     'name': '10',
#     'is_hd': True,
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2175069/c89312d74d496c2fdf8971a7632c1496/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2175069/c89312d74d496c2fdf8971a7632c1496/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2175069/c89312d74d496c2fdf8971a7632c1496/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2175069/c89312d74d496c2fdf8971a7632c1496/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2175069/c89312d74d496c2fdf8971a7632c1496/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2175069/c89312d74d496c2fdf8971a7632c1496/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2175069/c89312d74d496c2fdf8971a7632c1496/1200x900n'},
#     'photo_class': 'AUTO_VIEW_BACK_LEFT',
#     'name': '13',
#     'is_hd': True,
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2166310/5f2e094404434deb6ad0a52d27896a5a/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2166310/5f2e094404434deb6ad0a52d27896a5a/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2166310/5f2e094404434deb6ad0a52d27896a5a/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2166310/5f2e094404434deb6ad0a52d27896a5a/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2166310/5f2e094404434deb6ad0a52d27896a5a/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2166310/5f2e094404434deb6ad0a52d27896a5a/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2166310/5f2e094404434deb6ad0a52d27896a5a/1200x900n'},
#     'photo_class': 'AUTO_VIEW_BACK_LEFT',
#     'name': '12',
#     'is_hd': True,
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2069717/fc31fda0020994e353c3f92dcf00042a/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2069717/fc31fda0020994e353c3f92dcf00042a/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2069717/fc31fda0020994e353c3f92dcf00042a/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2069717/fc31fda0020994e353c3f92dcf00042a/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2069717/fc31fda0020994e353c3f92dcf00042a/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2069717/fc31fda0020994e353c3f92dcf00042a/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2069717/fc31fda0020994e353c3f92dcf00042a/1200x900n'},
#     'photo_class': 'AUTO_VIEW_SIDE_LEFT',
#     'name': '9',
#     'is_hd': True,
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2179909/e4329e6d3be42b14eefa7f00a8e7eff1/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2179909/e4329e6d3be42b14eefa7f00a8e7eff1/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2179909/e4329e6d3be42b14eefa7f00a8e7eff1/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2179909/e4329e6d3be42b14eefa7f00a8e7eff1/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2179909/e4329e6d3be42b14eefa7f00a8e7eff1/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2179909/e4329e6d3be42b14eefa7f00a8e7eff1/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2179909/e4329e6d3be42b14eefa7f00a8e7eff1/1200x900n'},
#     'photo_class': 'AUTO_VIEW_SIDE_LEFT',
#     'name': '8',
#     'is_hd': True,
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2195941/4691bb1285b9d0dc0f7ba04191f145e4/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2195941/4691bb1285b9d0dc0f7ba04191f145e4/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2195941/4691bb1285b9d0dc0f7ba04191f145e4/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2195941/4691bb1285b9d0dc0f7ba04191f145e4/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2195941/4691bb1285b9d0dc0f7ba04191f145e4/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2195941/4691bb1285b9d0dc0f7ba04191f145e4/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2195941/4691bb1285b9d0dc0f7ba04191f145e4/1200x900n'},
#     'photo_class': 'AUTO_VIEW_SALON_FRONT_RIGHT',
#     'name': '2',
#     'is_hd': True,
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2167160/41da573a6527a455f51c91e9d90f4ba7/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2167160/41da573a6527a455f51c91e9d90f4ba7/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2167160/41da573a6527a455f51c91e9d90f4ba7/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2167160/41da573a6527a455f51c91e9d90f4ba7/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2167160/41da573a6527a455f51c91e9d90f4ba7/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2167160/41da573a6527a455f51c91e9d90f4ba7/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2167160/41da573a6527a455f51c91e9d90f4ba7/1200x900n'},
#     'photo_class': 'AUTO_VIEW_SALON_FRONT_RIGHT',
#     'name': '7',
#     'is_hd': True,
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2194048/d09f01053543f24aaee17d4c6a08bc75/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2194048/d09f01053543f24aaee17d4c6a08bc75/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2194048/d09f01053543f24aaee17d4c6a08bc75/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2194048/d09f01053543f24aaee17d4c6a08bc75/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2194048/d09f01053543f24aaee17d4c6a08bc75/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2194048/d09f01053543f24aaee17d4c6a08bc75/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2194048/d09f01053543f24aaee17d4c6a08bc75/1200x900n'},
#     'photo_class': 'AUTO_VIEW_TORPEDO_LEFT',
#     'name': '5',
#     'is_hd': True,
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2198920/ca11a5d10c543ca9d486cb7768bcda38/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2198920/ca11a5d10c543ca9d486cb7768bcda38/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2198920/ca11a5d10c543ca9d486cb7768bcda38/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2198920/ca11a5d10c543ca9d486cb7768bcda38/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2198920/ca11a5d10c543ca9d486cb7768bcda38/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2198920/ca11a5d10c543ca9d486cb7768bcda38/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2198920/ca11a5d10c543ca9d486cb7768bcda38/1200x900n'},
#     'photo_class': 'AUTO_VIEW_PP_RIGHT',
#     'name': '4',
#     'is_hd': True,
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/1586061/155d17ab4d3d7c96c245dea5ffc05da3/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/1586061/155d17ab4d3d7c96c245dea5ffc05da3/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/1586061/155d17ab4d3d7c96c245dea5ffc05da3/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/1586061/155d17ab4d3d7c96c245dea5ffc05da3/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/1586061/155d17ab4d3d7c96c245dea5ffc05da3/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/1586061/155d17ab4d3d7c96c245dea5ffc05da3/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/1586061/155d17ab4d3d7c96c245dea5ffc05da3/1200x900n'},
#     'photo_class': 'AUTO_VIEW_DISK_RIGHT',
#     'name': '3',
#     'is_hd': True,
#     'preview': 'data:image/jpeg;base64,...'}],
#   'images_count': 13},
#  'sub_category': 'cars',
#  'vehicle_info': {'configuration': {'body_type': 'ALLROAD_5_DOORS',
#    'id': '20038323',
#    'doors_count': 5,
#    'human_name': 'Внедорожник 5 дв.',
#    'main_photo': {'name': 'configuration-photo',
#     'sizes': {'main': '//avatars.mds.yandex.net/get-verba/1540742/2a0000017762e9ca6d7c9a9434f2a8b525f0/gallery',
#      'mini-card': '//avatars.mds.yandex.net/get-verba/1540742/2a0000017762e9ca6d7c9a9434f2a8b525f0/minicard',
#      'mobile': '//avatars.mds.yandex.net/get-verba/1540742/2a0000017762e9ca6d7c9a9434f2a8b525f0/auto_main',
#      'orig': '//avatars.mds.yandex.net/get-verba/1540742/2a0000017762e9ca6d7c9a9434f2a8b525f0/orig',
#      'wizardv3mr': '//avatars.mds.yandex.net/get-verba/1540742/2a0000017762e9ca6d7c9a9434f2a8b525f0/wizardv3mr',
#      'cattouch': '//avatars.mds.yandex.net/get-verba/1540742/2a0000017762e9ca6d7c9a9434f2a8b525f0/cattouch'}}},
#   'complectation': {'id': '21078549',
#    'name': 'Premium 7S Sport',
#    'available_options': ['cruise-control',
#     'multi-wheel',
#     'xenon',
#     'heated-wash-system',
#     'airbag-passenger',
#     'navigation',
#     'lock',
#     'electro-mirrors',
#     'mirrors-heat',
#     'cooling-box',
#     'leather',
#     'seat-memory',
#     'front-seats-heat-vent',
#     'computer',
#     'seat-transformation',
#     'wheel-power',
#     'light-cleaner',
#     'airbag-rear-side',
#     'airbag-side',
#     'abs',
#     'wheel-leather',
#     'climate-control-1',
#     'auto-mirrors',
#     'esp',
#     'adaptive-light',
#     'usb',
#     'windcleaner-heat',
#     'front-centre-armrest',
#     'rear-camera',
#     'servo',
#     'electro-window-back',
#     '18-inch-wheels',
#     'hatch',
#     'body-mouldings',
#     'park-assist-f',
#     'rear-seats-heat',
#     'wheel-heat',
#     'condition',
#     'led-lights',
#     'music-super',
#     'park-assist-r',
#     'knee-airbag',
#     'airbag-driver',
#     'isofix',
#     'aux',
#     'electro-window-front',
#     'light-sensor',
#     'hcc',
#     'airbag-curtain',
#     'keyless-entry',
#     'passenger-seat-electric',
#     'alarm',
#     'paint-metallic',
#     'leather-gear-stick',
#     'blind-spot',
#     'start-button',
#     'ptf',
#     'rain-sensor',
#     'tyre-pressure',
#     'audiosystem-cd',
#     'migration-flag',
#     'front-seats-heat',
#     'bluetooth',
#     'wheel-configuration2',
#     'wheel-configuration1',
#     'immo',
#     '12v-socket',
#     'third-rear-headrest',
#     '360-camera']},
#   'equipment': {'cruise-control': True,
#    'tinted-glass': True,
#    'esp': True,
#    'adaptive-light': True,
#    'usb': True,
#    'windcleaner-heat': True,
#    'multi-wheel': True,
#    'xenon': True,
#    'audiosystem-tv': True,
#    'heated-wash-system': True,
#    'airbag-passenger': True,
#    'front-centre-armrest': True,
#    'navigation': True,
#    'roof-rails': True,
#    'lock': True,
#    'servo': True,
#    'electro-mirrors': True,
#    'electro-window-back': True,
#    '18-inch-wheels': True,
#    'multizone-climate-control': True,
#    'mirrors-heat': True,
#    'hatch': True,
#    'body-mouldings': True,
#    'dark-interior': True,
#    'park-assist-f': True,
#    'rear-seats-heat': True,
#    'leather': True,
#    'cooling-box': True,
#    'seat-memory': True,
#    'wheel-heat': True,
#    'led-lights': True,
#    'music-super': True,
#    'park-assist-r': True,
#    'knee-airbag': True,
#    'front-seats-heat-vent': True,
#    'airbag-driver': True,
#    'aux': True,
#    'isofix': True,
#    'electro-window-front': True,
#    'light-sensor': True,
#    'hcc': True,
#    'automatic-lighting-control': True,
#    'airbag-curtain': True,
#    'computer': True,
#    'keyless-entry': True,
#    'seat-transformation': True,
#    'alarm': True,
#    'passenger-seat-electric': True,
#    'light-cleaner': True,
#    'airbag-rear-side': True,
#    'paint-metallic': True,
#    'leather-gear-stick': True,
#    'ptf': True,
#    'start-button': True,
#    'blind-spot': True,
#    'rain-sensor': True,
#    'airbag-side': True,
#    'tyre-pressure': True,
#    'abs': True,
#    'bluetooth': True,
#    'front-seats-heat': True,
#    'wheel-leather': True,
#    'wheel-configuration2': True,
#    'wheel-configuration1': True,
#    'immo': True,
#    'third-row-seats': True,
#    'auto-mirrors': True,
#    '12v-socket': True,
#    '360-camera': True,
#    'third-rear-headrest': True},
#   'mark_info': {'code': 'LEXUS',
#    'name': 'Lexus',
#    'ru_name': 'Лексус',
#    'logo': {'name': 'mark-logo',
#     'sizes': {'logo': '//avatars.mds.yandex.net/get-verba/937147/2a00000179b3cbfe6c41c4c32d9250350c44/logo',
#      'big-logo': '//avatars.mds.yandex.net/get-verba/937147/2a00000179b3cbfe6c41c4c32d9250350c44/dealer_logo',
#      'black-logo': '//avatars.mds.yandex.net/get-verba/1540742/2a00000179b3cc1fdaa3950ce552f6de92b9/logo'}},
#    'numeric_id': '3166'},
#   'model_info': {'code': 'GX', 'name': 'GX', 'ru_name': 'GX'},
#   'steering_wheel': 'LEFT',
#   'super_gen': {'id': '20038320',
#    'name': 'II Рестайлинг',
#    'ru_name': '2 Рестайлинг',
#    'year_from': 2013,
#    'year_to': 2019,
#    'price_segment': 'PREMIUM',
#    'purpose_group': 'BUSINESS'},
#   'tech_param': {'gear_type': 'ALL_WHEEL_DRIVE',
#    'engine_type': 'GASOLINE',
#    'transmission': 'AUTOMATIC',
#    'id': '20038732',
#    'name': '460',
#    'nameplate': '460',
#    'displacement': 4608,
#    'power': 296,
#    'power_kvt': 218,
#    'human_name': '460 4.6 AT (296 л.с.) 4WD'},
#   'vendor': 'JAPANESE'},
#  'recommendation_tags': []}

# %%
# Out:
# 1
